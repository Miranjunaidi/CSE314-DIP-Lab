# %% [markdown]
# # Digital Image Processing Lab

# %% [markdown]
# ## Assignment by MTH Junaidi AP17110010074 of CSE B

# %% [markdown]
# ## Basic Operations and Intensity Transformation (Point Operations)

# %% [markdown]
# This is the first lab exercise and we are to achieve the following

# %% [markdown]
# 1. Perform the following operations using library functions </br>
#     a. Read, Display and write any color image in other formats.</br>
#     b. Find RED, GREEN and BLUE plane of the color image.</br>
#     c. Convert color image into gray scale image and binary image.</br>
#     d. Resize the image by one half and one quarter.</br>
#     e. Image rotates by 45, 90 and 180 degrees.</br>

# %% [markdown]
# We are using the conventional image of Lena popularaly used in this field

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
lena = mpimg.imread("lena.png")

# %%
lena.shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(lena)

# %%
sum(lena[0][0])/3
# Out:
# 0.6313725709915161

# %%
plt.imshow(lena)

# %%
temp1 =[]
temp2 = []
for i in range(256):
    for j in range(256):
        temp2.append(sum(lena[i][j])/3)
    temp1.append(temp2)
    temp2 =[]

# %%
plt.imshow(temp1)

# %%
lena.shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(temp1, cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(lena, cmap='gray', vmin=0, vmax=255)

# %%
a = np.array(temp1)

# %%
a.shape
# Out:
# (256, 256)

# %%
a[0][0]
# Out:
# 0.6313725709915161

# %%
plt.imshow(a, cmap='gray', vmin=0, vmax=1)

# %%
a
# Out:
# array([[0.63137257, 0.63137257, 0.6156863 , ..., 0.66274512, 0.66274512,
#         0.49411765],
#        [0.63137257, 0.63137257, 0.6156863 , ..., 0.67058825, 0.66274512,
#         0.49411765],
#        [0.63921571, 0.60784316, 0.62352943, ..., 0.58431375, 0.48627451,
#         0.24313726],
#        ...,
#        [0.21176471, 0.18039216, 0.20392157, ..., 0.34509805, 0.36078432,
#         0.35294119],
#        [0.16470589, 0.18039216, 0.18039216, ..., 0.3764706 , 0.40784314,
#         0.38431373],
#        [0.17254902, 0.19607843, 0.18039216, ..., 0.40784314, 0.40784314,
#         0.42352942]])

# %%
b = a*256

# %%
b
# Out:
# array([[161.63137817, 161.63137817, 157.61569214, ..., 169.66275024,
#         169.66275024, 126.49411774],
#        [161.63137817, 161.63137817, 157.61569214, ..., 171.67059326,
#         169.66275024, 126.49411774],
#        [163.63922119, 155.60784912, 159.62353516, ..., 149.58432007,
#         124.48627472,  62.24313736],
#        ...,
#        [ 54.21176529,  46.18039322,  52.20392227, ...,  88.3451004 ,
#          92.36078644,  90.35294342],
#        [ 42.16470718,  46.18039322,  46.18039322, ...,  96.37647247,
#         104.40784454,  98.38431549],
#        [ 44.1725502 ,  50.19607925,  46.18039322, ..., 104.40784454,
#         104.40784454, 108.42353058]])

# %%
lena_Greyscale = b

# %%
lena_Greyscale.shape
# Out:
# (256, 256)

# %% [markdown]
# ## This is the converted Grayscale Image acheved by array maupulation

# %%
plt.imshow(a, cmap='gray')

# %%
lena.shape[1]
# Out:
# 256

# %% [markdown]
# ## This is the re-sized image of 125 Px.

# %%
resized = cv2.resize(lena_Greyscale, (lena_Greyscale.shape[0] * 50//100,lena_Greyscale.shape[1] * 50//100))

# %%
plt.imshow(resized, cmap='gray')

# %% [markdown]
# ## Rotation of the image by 45 90 and 180 degree

# %%
center = (lena_Greyscale.shape[0]//2 , lena_Greyscale.shape[1]//2)

# %%
mask = cv2.getRotationMatrix2D(center, 45, 1)

# %%
rotated45 = cv2.warpAffine(lena_Greyscale, mask, (lena_Greyscale.shape[0],lena_Greyscale.shape[1]))

# %%
plt.imshow(rotated45, cmap='gray')

# %%
mask90 = cv2.getRotationMatrix2D(center, 90, 1)

# %%
rotated90 = cv2.warpAffine(lena_Greyscale, mask90, (lena_Greyscale.shape[0],lena_Greyscale.shape[1]))

# %%
plt.imshow(rotated90, cmap='gray')

# %%
mask180 = cv2.getRotationMatrix2D(center, 180, 1)

# %%
rotated180 = cv2.warpAffine(lena_Greyscale, mask180, (lena_Greyscale.shape[0],lena_Greyscale.shape[1]))

# %%
plt.imshow(rotated180, cmap='gray')

# %% [markdown]
# # Question 2

# %% [markdown]
# Create black and white images (A) of size 1024x1024. Which consists of alternativ
# horizontal lines of black and white? Each line is of size 128.<br>
# Create black and white images (B) of size 1024x1024. Which consists of alternative<br>
# vertical lines of black and white? Each line is of size128.Perform the following<br>
# operations on Image A and Image B.<br>
# a. Image addition of A and B<br>
# b. Subtraction of A and B<br>
# c. Multiplying Images of A and B<br>
# a. Create a grayscale image of size 256x1024. Intensity of image should vary<br>
# sinusoidal.<br>
# b. Create a white image of size 256x256, with black box of size 58x58 at centre.<br>

# %%
Image_A_Array = []
for i in range(1024):
    temps = []
    for j in range(1024):
        temps.append(1)
    Image_A_Array.append(temps)

# %%
Image_A_Array = np.array(Image_A_Array)

# %%
Image_A_Array.shape
# Out:
# (1024, 1024)

# %%
temp_index = 0
for i in range (1, (1024//128)+1):
    if i % 2 ==0:
        for j in range (128):
            Image_A_Array[temp_index] = Image_A_Array[temp_index]*0
            temp_index+=1
    if i % 2 ==1:
        for j in range (128):
            Image_A_Array[temp_index] = Image_A_Array[temp_index]*255
            temp_index+=1

# %%
plt.imshow(Image_A_Array, cmap='gray')

# %%
Image_A_Array.max()
# Out:
# 255

# %%
Image_B_Array = Image_A_Array.transpose()

# %%
plt.imshow(Image_B_Array, cmap='gray')

# %%
Added_Array = Image_A_Array + Image_B_Array

# %%
plt.imshow(Added_Array, cmap='gray')

# %%
Substracted_Array = Image_A_Array - Image_B_Array

# %%
plt.imshow(Substracted_Array, cmap='gray')

# %%
multiplied_array = Image_A_Array*Image_B_Array

# %%
plt.imshow(multiplied_array, cmap='gray')

# %%
arry_multiply_array = Image_A_Array.dot(Image_B_Array)

# %%
plt.imshow(arry_multiply_array, cmap='gray')

# %%
sine_image_Array = []
for i in range(256):
    temp= []
    for j in range(1024):
        temp.append(np.sin(np.deg2rad(j)))
    sine_image_Array.append(temp)

# %%
sine_image_Array = np.array(sine_image_Array)

# %%
sine_image_Array.shape
# Out:
# (256, 1024)

# %%
plt.imshow(sine_image_Array, cmap='gray')

# %%
box_image = []
for i in range(256):
    temp =[]
    for j in range(256):
        if i>=99 and i<157 and j>=99 and j<157:
            temp.append(0)
        else:
            temp.append(255)
    box_image.append(temp)

# %%
plt.imshow(box_image, cmap='gray')

# %% [markdown]
# # Question 3

# %% [markdown]
# Develop programs for following intensity transformation operation on a gray scale<br>
# image. Collect any gray scale image from any source. Process that image using these<br>
# operations.<br>
# a. Image negative<br>
# b. Log transformation and inverse log transform: s = c log (1+r), c is a const, r ≥ 0. s<br>
# is pixel intensity of output image, r is the pixel intensity of input image. Study thev
# effect of constant c on the quality of output image.<br>
# c. Power law transformation: Study the effect of different values of Gamma used in<br>
# this transformation.<br>
# d. Contrast stretching<br>
# e. Gray level slicing<br>

# %% [markdown]
# ## Image Negative

# %%
negative_image = []
for i in lena_Greyscale:
    temp = []
    for j in i:
        temp.append(255 - j)
    negative_image.append(temp)

# %%
plt.imshow(negative_image, cmap='gray')

# %% [markdown]
# ## Log Transform

# %%
log_image = []
for i in lena_Greyscale:
    temp = []
    for j in i:
        temp.append(0.01*np.log(1+j))
    log_image.append(temp)

# %%
plt.imshow(log_image, cmap='gray')

# %%
log_image = []
for i in lena_Greyscale:
    temp = []
    for j in i:
        temp.append(1000*np.log(1+j))
    log_image.append(temp)

# %%
plt.imshow(log_image, cmap='gray')

# %% [markdown]
# ## Power Law with different gamma Values

# %%
power_law_image = []
for i in lena_Greyscale:
    temp = []
    for j in i:
        temp.append(1*j**5)
    power_law_image.append(temp)

# %%
plt.imshow(power_law_image, cmap='gray')

# %%
power_law_image = []
for i in lena_Greyscale:
    temp = []
    for j in i:
        temp.append(1*j**10)
    power_law_image.append(temp)

# %%
plt.imshow(power_law_image, cmap='gray')

# %%
power_law_image = []
for i in lena_Greyscale:
    temp = []
    for j in i:
        temp.append(1*j**2)
    power_law_image.append(temp)

# %%
plt.imshow(power_law_image, cmap='gray')

# %% [markdown]
# ## Contrast Streaching

# %%
contast_streaching_image = []
for i in lena_Greyscale:
    temp = []
    for j in i:
        temp.append(j-1000)
    contast_streaching_image.append(temp)

# %%
plt.imshow(contast_streaching_image, cmap='gray')

# %%
contast_streaching_image = []
for i in lena_Greyscale:
    temp = []
    for j in i:
        temp.append(j-6)
    contast_streaching_image.append(temp)

# %%
plt.imshow(contast_streaching_image, cmap='gray')

# %% [markdown]
# ## Grey Level Slicing

# %%
Grey_level_image = []
for i in lena_Greyscale:
    temp = []
    for j in i:
        if j<2:
            temp.append(0)
        else:
            temp.append(j)
    Grey_level_image.append(temp)

# %%
plt.imshow(Grey_level_image, cmap='gray')
